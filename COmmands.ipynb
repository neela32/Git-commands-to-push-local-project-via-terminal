# %% [raw]
# Git command

# %% [markdown]
# git init

# %% [markdown]
# git add .

# %% [markdown]
# git commit -m "commit message/example my first commit"

# %% [markdown]
# git branch -M main

# %% [markdown]
# git remote add origin <github link (the https link from the repo you have created
# in your git account)>

# %% [markdown]
# git push -u origin main

# %% [markdown]
# git  checkout -b my-new-branch

# %% [markdown]
# git add .

# %%
Reference #https://youtu.be/PA-1_VlPCZc?si=V0DkqR5pCCV8N7vR
